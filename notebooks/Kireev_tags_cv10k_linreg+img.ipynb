# %% [markdown]
# # Load

# %%
import pandas as pd
import numpy as np

# %%
import json

# %%
def read_tags(f):
    line = json.loads(f)
    tags = line["tags"]
    return (" ".join([tag.replace(" ", "_") for tag in tags]))

# %%
def read_id(f):
    line = json.loads(f)
    _id = line["_id"]
    return (_id)

# %%
# %%time
with open("../data/train.json") as f:
    X_raw = np.array([read_tags(line) for line in f.readlines()])
# Out:
# CPU times: user 53.2 s, sys: 10.2 s, total: 1min 3s
# Wall time: 1min 3s

# %%
Y = pd.read_csv("../data/train_target.csv").target.values

# %% [markdown]
# # CV

# %% [markdown]
# Хорошие результаты могут быть при min_df=6.309573444801939e-05

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=10000)

# %%
cv.fit(X_raw)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=10000, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
cv.vocabulary_
# Out:
# {'логин': 6797,
#  'login': 2353,
#  'сообщества': 8861,
#  'интернет': 6135,
#  'сообщество': 8862,
#  'социальные': 8885,
#  'сети': 8688,
#  'бренд': 5163,
#  'карма': 6264,
#  'голосование': 5589,
#  'iphone': 2012,
#  'cisco': 708,
#  'apple': 313,
#  'судебное_разбирательство': 9064,
#  'афера': 4955,
#  'обман': 7380,
#  'мошенничество': 7156,
#  'nokia': 2841,
#  'meego': 2495,
#  'raspberry_pi': 3384,
#  'умный_дом': 9376,
#  'ios': 1997,
#  'co': 758,
#  'uk': 4191,
#  'filesystem': 1386,
#  'утилизация': 9435,
#  'реклама': 8386,
#  'hp': 1807,
#  'картриджи': 6272,
#  'hdr': 1749,
#  'amazon_web_services': 241,
#  'облачные_вычисления': 7372,
#  'информационная_безопасность': 6157,
#  'gps_мониторинг': 1659,
#  'репозиторий': 8415,
#  'linux': 2319,
#  'rhel': 3486,
#  'debian': 978,
#  'сайт': 8551,
#  'продажи': 8070,
#  'маркетинг': 6876,
#  'аккумулятор': 4793,
#  'батарея': 5009,
#  'суд': 9063,
#  'иск': 6176,
#  'total_commander': 4103,
#  'файловый_менеджер': 9461,
#  'проводник': 8043,
#  'клиентский_сервис': 6379,
#  'конфликт': 6555,
#  'студий': 9046,
#  'ruward': 3559,
#  'роботы': 8472,
#  'kinect': 2195,
#  'arduino': 339,
#  'тестирование': 9193,
#  'разработка': 8260,
#  'команда': 6437,
#  'agile': 199,
#  'высокая_производительность': 5453,
#  'высоконагруженные_приложения': 5456,
#  'локализация': 6806,
#  'jetbrains': 2107,
#  'rubymine': 3543,
#  'ruby': 3539,
#  'sass': 3593,
#  'less': 2277,
#  'puppet': 3295,
#  'jruby': 2131,
#  'gem': 1543,
#  'textmate': 4038,
#  'led': 2265,
#  'google_adsense': 1596,
#  'google_adwords': 1597,
#  'google': 1595,
#  'yahoo': 4645,
#  'физика': 9481,
#  'история_науки': 6202,
#  'звук': 5961,
#  'open_source': 2951,
#  'ubuntu': 4172,
#  'net': 2767,
#  'qt5': 3339,
#  'visual_studio_2012': 4337,
#  'сборка': 8595,
#  'qt': 3337,
#  'powershell': 3233,
#  'вирусы': 5355,
#  'криптография': 6663,
#  'warcraft': 4398,
#  'blizzard': 537,
#  'истории': 6194,
#  'игры': 6012,
#  '0day': 4,
#  'уязвимость': 9455,
#  'маршрутизаторы': 6894,
#  'css': 895,
#  'html': 1820,
#  'svg': 3952,
#  'инфографика': 6153,
#  'css3': 896,
#  'huawei': 1830,
#  'паранойя': 7626,
#  'саппорт': 8581,
#  'android': 258,
#  'libreoffice': 2292,
#  'office': 2908,
#  'ipod': 2025,
#  'музыка': 7166,
#  'воровство': 5401,
#  'защита': 5947,
#  'modx': 2629,
#  'клуб': 6388,
#  'мероприятие': 6961,
#  'системы_управления_версиями': 8737,
#  'mercurial': 2518,
#  'git': 1567,
#  'inkscape': 1937,
#  'графика': 5630,
#  'схемы': 9080,
#  'графические_редакторы': 5633,
#  'beta': 490,
#  'developer': 1022,
#  'mongodb': 2637,
#  'amazon_ec2': 237,
#  'nosql': 2852,
#  'mssql': 2694,
#  'ldap': 2257,
#  'active_directory': 157,
#  'sha': 3680,
#  'хэширование': 9675,
#  'javascript': 2094,
#  'html5': 1821,
#  'canvas': 641,
#  'asus': 380,
#  'ультрабук': 9366,
#  'windows_8': 4507,
#  'touch': 4104,
#  'ноутбук': 7346,
#  'сенсорный_экран': 8652,
#  'бытовая_техника': 5192,
#  'philips': 3124,
#  'iops': 1996,
#  'performance_tests': 3109,
#  'ssd': 3869,
#  'hdd': 1745,
#  'youtube': 4673,
#  'проигрыватель': 8108,
#  'утечка_данных': 9430,
#  'микроконтроллеры': 6997,
#  'net_micro_framework': 2775,
#  'mcu': 2481,
#  'chrome': 697,
#  'chromium': 703,
#  'webp': 4459,
#  'архитектура_приложений': 4917,
#  'кеширование': 6318,
#  'апдейт': 4890,
#  'jelly_bean': 2104,
#  'sony_xperia': 3816,
#  'рекомендательные_системы': 8397,
#  'google_maps': 1624,
#  'reactos': 3407,
#  'баумана': 5011,
#  'операционные_системы': 7484,
#  'образование': 7401,
#  'цензура': 9687,
#  'казахстан': 6232,
#  'nginx': 2818,
#  'php': 3133,
#  'security': 3644,
#  'ids': 1881,
#  'ips': 2028,
#  'waf': 4390,
#  'teradata': 4019,
#  'дизайн_сайтов': 5724,
#  'мозг': 7112,
#  'facebook': 1335,
#  'распознавание_лиц': 8305,
#  'защита_данных': 5949,
#  'кино': 6338,
#  'half': 1723,
#  'life': 2296,
#  'portal': 3213,
#  'responsive': 3467,
#  'layout': 2253,
#  'moon': 2646,
#  'литрес': 6774,
#  'копирайт': 6564,
#  'мини': 7017,
#  'пк': 7743,
#  'windows': 4497,
#  'membrana': 2504,
#  'дизайн': 5721,
#  'torrent': 4098,
#  'transmission': 4125,
#  'daemon': 934,
#  'htpc': 1825,
#  'планшет': 7758,
#  'обзор': 7359,
#  'notik': 2857,
#  'ru': 3536,
#  'blackberry_10': 527,
#  'портирование': 7902,
#  'code': 764,
#  'in': 1917,
#  'google_code': 1613,
#  'школьники': 9817,
#  'контест': 6535,
#  'google_summer_of_code': 1637,
#  'nexus_7': 2811,
#  'стивен_элоп': 9000,
#  'symbian': 3959,
#  'windows_phone': 4518,
#  'kvm': 2224,
#  'qemu': 3324,
#  'centos': 671,
#  'hosting': 1799,
#  'libvirt': 2293,
#  'the_pirate_bay': 4044,
#  'bittorrent': 518,
#  'web_2': 4421,
#  'мысли': 7189,
#  'статья': 8983,
#  'прокрастинация': 8113,
#  'лень': 6744,
#  'рабочий_процесс': 8216,
#  'учись_работать': 9451,
#  'геймификация': 5508,
#  'meizu_mx2': 2503,
#  'железо': 5844,
#  'разборка': 8236,
#  'dosbox': 1107,
#  'doom': 1105,
#  'старые_игры': 8973,
#  'free': 1460,
#  'lance': 2237,
#  'фриланс': 9567,
#  'wpf': 4580,
#  'silverlight': 3714,
#  'playstation': 3177,
#  'gamedev': 1512,
#  'системное_программирование': 8729,
#  'демосцена': 5683,
#  'дайджест': 5649,
#  'новости': 7323,
#  'js': 2132,
#  'интересное': 6132,
#  'браузеры': 5159,
#  'ресурсы': 8425,
#  'ссылки': 8951,
#  'ссылки_на_сми': 8952,
#  'веб': 5221,
#  'jquery': 2127,
#  'microsoft': 2541,
#  'будущее': 5178,
#  'домены': 5792,
#  'icann': 1857,
#  'new_gtld': 2797,
#  'web': 4419,
#  'биоинформатика': 5083,
#  '11': 11,
#  'python': 3315,
#  'boost': 565,
#  'модуль': 7109,
#  'гибрид': 5547,
#  'скрипт': 8763,
#  'python3': 3317,
#  'класс': 6366,
#  'class': 720,
#  'embedded': 1215,
#  'converter': 834,
#  'конвертер': 6499,
#  'box': 575,
#  'облачное_хранилище': 7371,
#  'скидка': 8751,
#  'акция': 4809,
#  'com': 786,
#  'zend': 4678,
#  'собеседование': 8820,
#  'архитектура': 4915,
#  'безопасность': 5021,
#  'hr': 1812,
#  'silex': 3710,
#  'kendo_ui': 2172,
#  'история_интернета': 6199,
#  'tutorial': 4147,
#  'imac': 1900,
#  'appstore': 329,
#  'wi': 4476,
#  'fi_роутер': 1377,
#  'мобильный_веб': 7085,
#  'мобильная_разработка': 7059,
#  'мобильное_приложение': 7066,
#  'google_earth': 1617,
#  'angularjs': 281,
#  'билл_гейтс': 5077,
#  'пожертвования': 7833,
#  'openvpn': 2984,
#  'vpn': 4370,
#  'проекты': 8106,
#  'процессы': 8165,
#  'работа': 8196,
#  'java': 2086,
#  'ioc_контейнеры': 1992,
#  'spring': 3846,
#  'часы': 9724,
#  'телефон': 9149,
#  'sim': 3718,
#  'связь': 8625,
#  'mp3': 2668,
#  'bluetooth': 550,
#  'sdk': 3629,
#  'туториал': 9321,
#  'шахматы': 9796,
#  'альфа': 4826,
#  'бета': 5064,
#  'приложения': 8011,
#  'asp': 367,
#  'net_mvc': 2776,
#  'http': 1826,
#  'нефть': 7302,
#  'россия': 8503,
#  'apple_iphone': 315,
#  'перевод': 7673,
#  'интервью': 6127,
#  'статистика': 8974,
#  'обработка_данных': 7392,
#  'анализ_данных': 4833,
#  'lte': 2370,
#  'umpc': 4198,
#  'мегафон': 6932,
#  'yota': 4668,
#  '4g': 98,
#  'антенна': 4871,
#  'гарнитура': 5497,
#  'windows_7': 4505,
#  'проблема': 8035,
#  'облако': 7366,
#  'биткоин': 5094,
#  'asic': 361,
#  'iptv': 2031,
#  'server': 3665,
#  'rozetked': 3517,
#  'kickstarter': 2191,
#  'параллельные_вычисления': 7624,
#  'openmp': 2971,
#  'opencl': 2955,
#  'erlang': 1259,
#  'dvd': 1154,
#  'наука': 7253,
#  'публикации': 8176,
#  'издательское_дело': 6038,
#  'panasonic': 3039,
#  'notebook': 2853,
#  'basecamp': 463,
#  'mobile_apps': 2596,
#  'управление_проектами': 9397,
#  'релизы': 8407,
#  'фрилансеры': 9569,
#  'заказчики': 5903,
#  'motorola': 2659,
#  'патенты': 7653,
#  'h264': 1706,
#  'логика': 6796,
#  'android_4': 260,
#  'node': 2837,
#  'promises': 3272,
#  'поиск': 7840,
#  'интранет': 6149,
#  'юмор': 9966,
#  'php5': 3134,
#  'fpm': 1453,
#  'sendmail': 3656,
#  'вода': 5375,
#  'нанотехнологии': 7234,
#  'управление_людьми': 9392,
#  'управление_персоналом': 9393,
#  'управление_проектами_и_командой': 9398,
#  'human_resources': 1834,
#  'мотивация': 7151,
#  'мотивация_персонала': 7152,
#  'краудсорсинг': 6636,
#  'рейтинг': 8379,
#  'стартап': 8969,
#  'космонавтика': 6607,
#  'астронавты': 4926,
#  'пилотируемая_космонавтика': 7723,
#  'алгоритмы': 4813,
#  'книга': 6395,
#  'дополненная_реальность': 5796,
#  'rss': 3524,
#  'bootstrap': 568,
#  'фреймворк': 9563,
#  'pocketbook': 3194,
#  'mysql': 2732,
#  'cad': 628,
#  'autocad': 411,
#  'программирование': 8054,
#  'intel': 1953,
#  'jquery_plugins': 2129,
#  'select': 3648,
#  'разработка_под_android': 8268,
#  'doc': 1087,
#  'картинки': 6269,
#  'nagios': 2740,
#  'мониторинг': 7130,
#  'proliant': 3269,
#  'snmp': 3782,
#  '2013': 41,
#  'crowdsourcing': 879,
#  'инвестиции': 6079,
#  'мобильная_коммерция': 7058,
#  'мобильный_платеж': 7089,
#  'sms': 3771,
#  'биллинг': 5078,
#  'платежи': 7766,
#  'smalltalk': 3754,
#  'tdd': 3993,
#  'ооп': 7476,
#  'vdi': 4285,
#  'app': 308,
#  'rds': 3399,
#  'virtualization': 4325,
#  'виртуализация': 5335,
#  'системное_администрирование': 8727,
#  'timelapse': 4066,
#  'gopro': 1647,
#  'сделай_сам': 8629,
#  '3d': 75,
#  'текстуры': 9130,
#  'облака': 7365,
#  'ibm': 1850,
#  'история': 6196,
#  'электронная_коммерция': 9903,
#  'кредитные_карты': 6645,
#  'vnc': 4357,
#  'xorg': 4628,
#  'linux_desktop': 2321,
#  'ошибки': 7595,
#  'хабр': 9598,
#  'баг': 4965,
#  'мистика': 7039,
#  'стартапы': 8972,
#  'риски': 8447,
#  'менеджмент': 6954,
#  'blackberry': 526,
#  'смартфон': 8799,
#  'видеообзор': 5304,
#  'asterisk': 377,
#  '1с': 31,
#  'crm': 872,
#  'ami': 246,
#  'google_chrome': 1609,
#  'эффективность': 9951,
#  'поисковые_системы': 7857,
#  'методология_разработки': 6978,
#  'ресторан': 8419,
#  'бар': 5002,
#  'кафе': 6292,
#  'скидки': 8752,
#  'санкт': 8578,
#  'петербург': 7710,
#  'twitter_api': 4157,
#  'net_4': 2769,
#  'net_3': 2768,
#  'pycharm': 3309,
#  'vagrant': 4266,
#  'django': 1071,
#  'подборка': 7809,
#  'laravel': 2242,
#  'symfony': 3960,
#  'apc': 301,
#  'zend_framework': 4680,
#  'владимир_путин': 5364,
#  'mvc': 2716,
#  'электронные_книги': 9909,
#  'киберпреступность': 6327,
#  'eset': 1272,
#  'google_docs': 1615,
#  'google_drive': 1616,
#  'leap_motion': 2262,
#  'ux_design': 4262,
#  'responsive_design': 3468,
#  'responsive_web_design': 3469,
#  'webm': 4453,
#  'video_streaming': 4307,
#  'эмоции': 9926,
#  'менеджер': 6950,
#  'задача': 5892,
#  'bill_gates': 502,
#  'reddit': 3424,
#  'интерактив': 6126,
#  'беспроводная_зарядка': 5054,
#  'nexus_4': 2809,
#  'роутер': 8511,
#  'ibm_watson': 1853,
#  'диагностика': 5715,
#  'настольные_игры': 7248,
#  'механика': 6985,
#  'mega': 2498,
#  'вознаграждение': 5384,
#  'ruby_on_rails': 3540,
#  'fix': 1412,
#  'patch': 3063,
#  'json': 2136,
#  'vlc': 4351,
#  'торрент': 9259,
#  'потоковое_видео': 7923,
#  'continuous_integration': 830,
#  'мастер_кит': 6902,
#  'светофор': 8611,
#  'аспирантура': 4921,
#  'взгляд_изнутри': 5279,
#  'швейцария': 9798,
#  'epfl': 1252,
#  'mpls': 2674,
#  'mikrotik': 2557,
#  'routeros': 3514,
#  'juniper_srx': 2147,
#  'flickr': 1423,
#  'китай': 6348,
#  'сша': 9089,
#  'журналы': 5875,
#  'game': 1506,
#  'exe': 1308,
#  'практика': 7956,
#  'интерфейсы': 6147,
#  'liveidea': 2338,
#  'постановка_целей': 7911,
#  'smartprogress': 3762,
#  'личностный_рост': 6787,
#  'карьера': 6276,
#  'планирование': 7753,
#  'devcon': 1019,
#  'конференции': 6547,
#  'конкурсы': 6512,
#  'достижения': 5804,
#  'imagine_cup': 1906,
#  'imagine_cup_2013': 1908,
#  'консоль': 6516,
#  'кастомизация': 6287,
#  'bash': 465,
#  'howto': 1806,
#  'makefile': 2428,
#  'grid': 1678,
#  'песочница': 7709,
#  'старое_железо': 8965,
#  'хабрахабр': 9610,
#  'профиль': 8154,
#  'встреча': 5427,
#  'компания': 6470,
#  'экран': 9867,
#  'рефакторинг': 8430,
#  'шпаргалка': 9826,
#  'экология': 9860,
#  'hewlett': 1763,
#  'packard': 3032,
#  'принтеры': 8020,
#  'системы_хранения_данных': 8738,
#  'oppo': 2997,
#  'alconost': 213,
#  'video': 4306,
#  'бэкап': 5193,
#  'gmail': 1577,
#  'how_to': 1805,
#  'ролик': 8486,
#  'steve_blank': 3906,
#  'customer_development': 917,
#  'startup': 3891,
#  'vc': 4280,
#  'investment': 1987,
#  'product_development': 3252,
#  'стив_бланк': 8994,
#  'инвесторы': 6083,
#  'download': 1111,
#  'поисковые_сервисы': 7856,
#  'партнерство': 7642,
#  'обновления': 7387,
#  'windows_update': 4532,
#  'patchtuesday': 3065,
#  'mac_os_x': 2398,
#  'nodejs': 2838,
#  'шаблонизатор': 9784,
#  'sharepoint_2010': 3686,
#  'datetime': 959,
#  'хобби': 9645,
#  'бизнес': 5068,
#  'электроника': 9899,
#  'разработка_электроники': 8278,
#  'приключения': 8004,
#  'спорт': 8926,
#  'баланс': 4984,
#  'любовь': 6827,
#  'opera': 2987,
#  'erp': 1260,
#  'toc': 4085,
#  'erp_системы': 1261,
#  'инопланетяне': 6104,
#  'twitter': 4156,
#  'твиттер': 9120,
#  'блоги': 5114,
#  'инвестирование': 6078,
#  'опрос': 7491,
#  'итоги': 6217,
#  'отчет': 7562,
#  'разработка_под_ios': 8269,
#  'mobile_development': 2598,
#  'accessibility': 140,
#  'вспомогательные_технологии': 5425,
#  'wcag': 4414,
#  'dependency_injection': 1007,
#  'inversion_of_control': 1986,
#  'postgresql': 3223,
#  'tcl': 3991,
#  'tk': 4079,
#  'regexp': 3439,
#  'regular_expressions': 3441,
#  'безопасность_веб': 5023,
#  'приложений': 8010,
#  'обфускация': 7423,
#  'sdl': 3630,
#  'телефоны': 9152,
#  'база_данных': 4969,
#  'switch': 3957,
#  'tree': 4128,
#  'деревья': 5695,
#  'структуры_данных': 9040,
#  'cpp': 860,
#  'adobe': 178,
#  'flash': 1415,
#  'windows_phone_7': 4519,
#  'смартфоны': 8800,
#  'bitcoin': 513,
#  'вконтакте': 5360,
#  'vk': 4345,
#  'cc': 655,
#  'firefox': 1399,
#  'защищенные_телефоны': 5957,
#  'математика': 6908,
#  'день_святого_валентина': 5690,
#  'pdf': 3089,
#  'saas': 3567,
#  'helpdesk': 1757,
#  'выборы': 5440,
#  'политика': 7880,
#  'взлом': 5280,
#  'mtgox': 2698,
#  'binding': 507,
#  'mvvm': 2721,
#  'framework': 1456,
#  'api': 303,
#  'conficker': 816,
#  'сессии': 8678,
#  'redis': 3427,
#  'запросы': 5933,
#  'решение': 8437,
#  'маршрутизация': 6895,
#  'сетевые_технологии': 8687,
#  'техническая_поддержка': 9206,
#  'техподдержка': 9217,
#  'cmd': 749,
#  'windows_server_2012': 4527,
#  'edge': 1184,
#  'iscsi': 2046,
#  'pxe': 3308,
#  'perl': 3110,
#  'poe': 3196,
#  'zigbee': 4692,
#  'yii_framework': 4664,
#  'gtd': 1693,
#  'заметки': 5921,
#  'skyforge': 3739,
#  'mail': 2422,
#  'acer': 141,
#  'aspire': 369,
#  'webkit': 4451,
#  'ит': 6213,
#  'аутсорсинг': 4954,
#  'servicedesk': 3669,
#  'seo': 3657,
#  'seo_оптимизация': 3658,
#  'seo_продвижение': 3659,
#  'продвижение_сайта': 8082,
#  'openoffice': 2973,
#  'свободное_по': 8616,
#  'rtb': 3528,
#  'ликбез': 6761,
#  'myspace': 2731,
#  'смерть': 8803,
#  'сервисы': 8667,
#  'научно': 7256,
#  'популярное': 7896,
#  'чёрные_дыры': 9780,
#  'стивен_хокинг': 8999,
#  'книги': 6398,
#  'samsung': 3582,
#  'malware': 2431,
#  'static': 3896,
#  'like': 2306,
#  'социальная_сеть': 8884,
#  'дети': 5698,
#  'австралия': 4721,
#  'производительность': 8109,
#  'ajax': 208,
#  'итоги_конкурса': 6219,
#  'тесты': 9203,
#  'краудфандинг': 6637,
#  'кикстартер': 6335,
#  'crowdfunding': 878,
#  'java_ee': 2090,
#  'jvm': 2151,
#  'правописание': 7953,
#  'jenkins': 2105,
#  'копирайтинг': 6566,
#  'thepiratebay': 4049,
#  'будущее_рядом': 5182,
#  'emc': 1221,
#  'миграция': 6989,
#  'цод': 9710,
#  'авария': 4716,
#  'disaster_recovery': 1061,
#  'переезд': 7683,
#  'хранение_данных': 9664,
#  'схд': 9077,
#  'синхронизация': 8713,
#  'репликация': 8414,
#  'aws': 435,
#  'ebs': 1173,
#  'veeam': 4288,
#  'vmware': 4354,
#  'hyper': 1839,
#  'azure': 436,
#  'amazon': 236,
#  'redmine': 3429,
#  'wiki': 4483,
#  'encryption': 1234,
#  'safari': 3569,
#  'lua': 2372,
#  'английский_язык': 4857,
#  'английский': 4856,
#  'иностранные_языки': 6106,
#  'изучение_иностранных_языков': 6054,
#  'теория_относительности': 9175,
#  'xcode': 4607,
#  'debugging': 982,
#  'programming': 3260,
#  'оффшор': 7577,
#  'найм': 7219,
#  'увольнение': 9344,
#  '2гис': 64,
#  'state_machine': 3895,
#  'конечный_автомат': 6504,
#  'adobe_photoshop': 182,
#  'исходный_код': 6211,
#  'ulmart': 4194,
#  'windows_rt': 4522,
#  'планшеты': 7762,
#  'детские_приложения': 5700,
#  'тестирование_приложений': 9197,
#  'unit': 4206,
#  'testing': 4029,
#  'модульное_тестирование': 7110,
#  'рынок': 8540,
#  '2can': 56,
#  'square': 3866,
#  'подарки': 7805,
#  'малый_бизнес': 6856,
#  'ua': 4165,
#  'id': 1869,
#  'история_создания': 6204,
#  'ping': 3159,
#  'icmp': 1862,
#  'доступ_в_интернет': 5806,
#  'настройка': 7249,
#  'для_начинающих': 5761,
#  'вредные_советы': 5416,
#  'sdn': 3631,
#  'openflow': 2961,
#  'парсинг': 7636,
#  'бд': 5015,
#  'общение': 7425,
#  'знакомства': 5982,
#  'программисты': 8060,
#  'ос': 7520,
#  'автомобиль': 4740,
#  'toyota': 4109,
#  'nissan': 2828,
#  'honda': 1796,
#  'metro_ui': 2532,
#  'gui': 1698,
#  'юзабилити': 9959,
#  'stylus': 3931,
#  'яндекс': 9996,
#  'почта': 7928,
#  'препроцессоры': 7981,
#  'badoo': 456,
#  'баду': 4967,
#  'автоматизация_тестирования': 4733,
#  'teamcity': 3995,
#  'jira': 2110,
#  'сотрудничество': 8876,
#  'компании': 6468,
#  'принтер': 8019,
#  'печать': 7714,
#  'моделирование': 7099,
#  'сканер': 8745,
#  'тренды': 9292,
#  'робототехника': 8470,
#  'космос': 6609,
#  'пароли': 7631,
#  'безопасность_в_сети': 5022,
#  'кроссплатформенность': 6673,
#  'vista': 4331,
#  'сервис': 8665,
#  'успех': 9418,
#  'цель': 9685,
#  'unity3d': 4211,
#  'optimization': 2999,
#  '2d_игры': 58,
#  'языки_программирования': 9994,
#  'кодобред': 6418,
#  'ideas': 1877,
#  'идея': 6023,
#  'ipsec': 2029,
#  'on': 2929,
#  'радио': 8220,
#  'катастрофы': 6291,
#  'манга': 6860,
#  'patterns_and_practices': 3070,
#  'prism': 3244,
#  'pcl': 3086,
#  'nuget': 2868,
#  'wp8': 4578,
#  'winrt': 4539,
#  'устройство': 9428,
#  'мышь': 7196,
#  'клавиатура': 6360,
#  'dsl': 1144,
#  'steam': 3900,
#  'sale': 3575,
#  'next': 2806,
#  'unix': 4219,
#  'стив_джобс': 8996,
#  'шаблоны_проектирования': 9789,
#  'solid': 3807,
#  'domain': 1101,
#  'test': 4027,
#  'driven_development': 1125,
#  'postgis': 3221,
#  'вирусы_и_антивирусы': 5356,
#  'юлмарт': 9965,
#  'sony_vaio': 3815,
#  'авторское_право': 4753,
#  'интеллектуальная_собственность': 6123,
#  'fi': 1376,
#  'роуминг': 8510,
#  'социальные_сети': 8891,
#  'астероид': 4924,
#  'астероиды': 4925,
#  'кометная_опасность': 6449,
#  'астрономия': 4927,
#  'астрофизика': 4928,
#  'краудинвестинг': 6635,
#  'прибыль': 7989,
#  'медицина': 6942,
#  'защита_персональных_данных': 5954,
#  'роскомнадзор': 8489,
#  'google_analytics': 1598,
#  'аналитика': 4842,
#  'счетчик': 9088,
#  'presto': 3240,
#  'opensourse': 2978,
#  'blender': 534,
#  'smarty': 3765,
#  'twig': 4152,
#  'model': 2621,
#  'проектирование': 8096,
#  'мобильные_приложения': 7074,
#  'retention': 3476,
#  'помощь': 7893,
#  'урок': 9412,
#  'совет': 8828,
#  'windows_azure': 4510,
#  'англия': 4858,
#  'иммиграция': 6064,
#  'seedcamp': 3645,
#  'realtime': 3414,
#  'unity': 4210,
#  'демпинг': 5684,
#  'государственные_органы': 5613,
#  'samsung_electronics': 3583,
#  'самсунг': 8575,
#  'phone': 3128,
#  'ipad': 2011,
#  'приложения_для_iphone': 8013,
#  'обучение_с_подкреплением': 7422,
#  'us': 4240,
#  'ciklum': 706,
#  'services': 3670,
#  'jquery_ui': 2130,
#  'surface': 3949,
#  'freepbx': 1467,
#  'sip': 3728,
#  'elastix': 1200,
#  'обучение': 7416,
#  'ultimaker': 4195,
#  'tizen': 4077,
#  'отказоустойчивость': 7539,
#  'fpga': 1452,
#  'вебальта': 5228,
#  'партнерские_программы': 7641,
#  'торговая_марка': 9253,
#  'судебный_процесс': 9068,
#  'nexus': 2808,
#  'dsp': 1146,
#  'компьютерная_графика': 6482,
#  'сжатие_данных': 8694,
#  'skype': 3743,
#  'voip': 4362,
#  'concurrency': 814,
#  'webgl': 4446,
#  'kanban': 2159,
#  'lean': 2260,
#  'ea': 1164,
#  'electronic_arts': 1203,
#  'reader': 3410,
#  'exception': 1303,
#  'translation': 4124,
#  'интерфейс': 6145,
#  'прототипирование': 8143,
#  'разработка_приложений': 8272,
#  'chrome_os': 700,
#  'розничная_торговля': 8481,
#  'розыгрыш': 8482,
#  'seagate': 3636,
#  'виджет': 5319,
#  'фейсбук': 9475,
#  'router': 3513,
#  'microsoft_office': 2547,
#  'eula': 1289,
#  'матрица': 6918,
#  'зима': 5977,
#  'серверы': 8662,
#  'апгрейд': 4889,
#  'жизнь': 5862,
#  'fun': 1488,
#  'div': 1066,
#  'вопрос': 5395,
#  'lightbox': 2302,
#  'cloud_storage': 738,
#  'wlan': 4552,
#  'корпоративная_сеть': 6579,
#  'juniper': 2145,
#  'juniper_networks': 2146,
#  'aruba': 353,
#  'cisco_systems': 711,
#  'платформа': 7777,
#  'монополия': 7141,
#  'конкуренция': 6507,
#  'jasmine': 2085,
#  'bdd': 477,
#  'микросхема': 7007,
#  'мультиклет': 7173,
#  'z80': 4675,
#  'метро': 6982,
#  'kde': 2166,
#  'os': 3009,
#  'usability': 4242,
#  'энергия': 9932,
#  'идеи': 6017,
#  'simple_science': 3721,
#  'опыты': 7509,
#  'эксперименты': 9873,
#  'gtv': 1697,
#  'goldphone': 1594,
#  'своими_руками': 8620,
#  'видео': 5286,
#  'свч': 8622,
#  'vb': 4276,
#  'kiss': 2201,
#  'ddd': 969,
#  'coffeescript': 776,
#  'diy': 1068,
#  'htc_hd2': 1816,
#  'computer_vision': 811,
#  'геолокация': 5536,
#  'geolocation': 1555,
#  'онлайн_игры': 7466,
#  'мобильные_игры': 7070,
#  'foursquare': 1449,
#  'btc': 598,
#  'ким_дотком': 6336,
#  'here': 1759,
#  'карты': 6273,
#  'навигация': 7206,
#  'ноутбуки': 7347,
#  'профилактика': 8152,
#  'взаимоотношения': 5277,
#  'саморазвитие': 8572,
#  ...}

# %%
# для собственных рассчетов
X_cv = cv.transform(X_raw)

# %%
# %who
# Out:
# CountVectorizer	 LinearRegression	 X_raw	 X_test	 X_test_raw	 X_train	 X_train_raw	 Y	 Y_test
# Y_train	 cv	 f	 json	 np	 pd	 pickle	 read_id	 read_tags
# reg	 train_test_split

# %%
del X_train_raw

# %% [markdown]
# # Add feature

# %%
import pickle

# %%
X_img_train = pickle.load(open("../features/imgtagcount_train.pickle", "rb"))

# %%
X = np.concatenate([X_cv.toarray(), X_img_train], axis=1)

# %%
del X_cv
del X_img_train

# %% [markdown]
# # Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=0)

# %%
del X

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression(fit_intercept=True)

# %%
reg.fit(X_train, Y_train)

# %%
Y_prediction = reg.predict(X_test)

# %% [markdown]
# # Evaluate

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(Y_test, Y_prediction)

# %% [markdown]
# # Validation

# %%
# %%time
with open("../data/test.json") as f:
    V_raw = np.array([read_tags(line) for line in f.readlines()])
# Out:
# CPU times: user 25.2 s, sys: 4.56 s, total: 29.7 s
# Wall time: 36.3 s

# %%
# %%time
V_result = pd.read_json("../data/test.json", lines=True)[["_id"]].rename(columns={"_id": "url"})
# Out:
# CPU times: user 15.6 s, sys: 2.99 s, total: 18.6 s
# Wall time: 18.6 s

# %%
V = cv.transform(V_raw)

# %%
# Для передачи коллегам
pickle.dump(V, open("../features/tags_cv10k_test.pickle", "wb"))

# %%
V_result["target"] = reg.predict(V)

# %%
output_name = "../results/tags_cv10k_linreg.csv"

# %%
V_result.to_csv(output_name, index=False)

# %%
# !head $output_name
# Out:
# url,target
# https://geektimes.ru/post/87455/,2.768101213216765
# https://geektimes.ru/post/87452/,3.3519307618257663
# https://geektimes.ru/post/87459/,3.4621333717370235
# https://habrahabr.ru/post/87461/,2.646380031783634
# https://habrahabr.ru/post/5754/,1.790165538470128
# https://geektimes.ru/post/87460/,2.4988841297807527
# https://geektimes.ru/post/87462/,2.5311992680679003
# https://habrahabr.ru/post/87467/,2.4729260789303855
# https://habrahabr.ru/post/87464/,2.896418513861229
